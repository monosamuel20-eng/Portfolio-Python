# %% [markdown]
# Variables in Python

# %%
x = 22
print(x)
# Out:
# 22

# %%
x = 'ice cream is my favorite' + '.'
print (x)
# Out:
# ice cream is my favorite.

# %%
x = 1
y = 5
z = 6
print(x+y+z)
# Out:
# 12

# %%
x = 'ice cream'
y = 3
print(x,y)
# Out:
# ice cream 3

# %% [markdown]
# Data Types

# %%
type(-12 + 100)
# Out:
# int

# %%
type(12 + 10.25)
# Out:
# float

# %%
type(12 + 3j)
# Out:
# complex

# %%
#Boolean
type(False)
# Out:
# bool

# %%
type(1>5)
# Out:
# bool

# %%
#Strings

'single Quote'
# Out:
# 'single Quote'

# %%
"Double Quote"
# Out:
# 'Double Quote'

# %%
a = 'Hello World'

# %%
print(a[:5])
# Out:
# Hello

# %%
a + a
# Out:
# 'Hello WorldHello World'

# %%
a*2
# Out:
# 'Hello WorldHello World'

# %%
#list
[1,2,3]
# Out:
# [1, 2, 3]

# %%
['cookie dough', 'Strawberry', 'Chocolate']
# Out:
# ['cookie dough', 'Strawberry', 'Chocolate']

# %%
['Vannila', 3, 'Scoop', 'spoon', True]
# Out:
# ['Vannila', 3, 'Scoop', 'spoon', True]

# %%
ice_cream =['cookie dough', 'Strawberry', 'Chocolate']
ice_cream.append('salted caremel')
ice_cream
# Out:
# ['cookie dough', 'Strawberry', 'Chocolate', 'salted caremel']

# %%
ice_cream[0] = 'Butter'
ice_cream
# Out:
# ['Butter', 'Strawberry', 'Chocolate', 'salted caremel']

# %%
nest_list = ['Vannila', 3, ['Scoop', 'spoon'], True]

# %%
#tuple
tuple_scoops = (1,2,3,2,1)

# %%
type(tuple_scoops)
# Out:
# tuple

# %%
#Sets

daily_pints = {1,2,3}

# %%
type(daily_pints)
# Out:
# set

# %%
print(daily_pints)
# Out:
# {1, 2, 3}

# %%
#dictionaries
#key/pair

dict_cream = {'name': 'mono samuel', 'weekly intake': 5, 'favorite ice cream': ['MCC', 'Chocolate']}

# %%
type(dict_cream)
# Out:
# dict

# %%
print(dict_cream)
# Out:
# {'name': 'mono samuel', 'weekly intake': 5, 'favorite ice cream': ['MCC', 'Chocolate']}

# %%
dict_cream.values()
# Out:
# dict_values(['mono samuel', 5, ['MCC', 'Chocolate']])

# %%
dict_cream.items()
# Out:
# dict_items([('name', 'mono samuel'), ('weekly intake', 5), ('favorite ice cream', ['MCC', 'Chocolate'])])

# %%
dict_cream['name']
# Out:
# 'mono samuel'

# %%
dict_cream['name'] = 'Christine hda'
print(dict_cream)
# Out:
# {'name': 'Christine hda', 'weekly intake': 5, 'favorite ice cream': ['MCC', 'Chocolate']}

# %%
dict_cream.update({'name':'Christine hda', 'weekly intake': 10, 'weight': 300})
print(dict_cream)
# Out:
# {'name': 'Christine hda', 'weekly intake': 10, 'favorite ice cream': ['MCC', 'Chocolate'], 'weight': 300}

# %%
del dict_cream['weight']
print(dict_cream)
# Out:
# {'name': 'Christine hda', 'weekly intake': 10, 'favorite ice cream': ['MCC', 'Chocolate']}
